# %% [markdown]
# <a href="https://colab.research.google.com/github/Lariiuki/Pos-Deep-Learning/blob/main/Imagem_analise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Analise2 - Cod_CCot_Cot - Custo.csv')

# %%
df.head()
# Out:
#        Modelo  duration_minimo  duration_maximo  duration_medio  \
# 0   gpt-5/CoT            19.18            59.68         44.0144
# 1  gpt-5/CoD1            20.26            58.67         40.3700
# 2  gpt-5/CoD2            17.51            57.90         41.4780
# 3  gpt-5/CoD3            17.47            57.73         41.1870
# 4  gpt-5/CCoT            13.89            45.74         27.0835
#
#   duration_total  custo_minimo  custo_maximo  custo_media custo_diff media  \
# 0         880,28      0.017556      0.038811     0.028681                0
# 1         807,40      0.017151      0.034556     0.027429        -0,001252
# 2         829,56      0.015899      0.036249     0.027456        -0,001225
# 3         823,74      0.015875      0.037004     0.027417        -0,001264
# 4         541,67      0.017621      0.044015     0.028921          0,00024
#
#   custo_total porc_total
# 0    0,573625          0
# 1     0,54858      -4,37
# 2    0,549115      -4,27
# 3    0,548345      -4,41
# 4    0,578420       0,84

# %%
colunas_float = ["duration_minimo", "duration_maximo", "duration_medio",
                 "custo_minimo", "custo_maximo", "custo_media"]

for col in colunas_float:
    df[col] = df[col].str.replace(",", ".").astype(float)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

# Gráfico de barras
bars = plt.bar(df["Modelo"], df["duration_medio"], color='skyblue', width=0.5)

# Adicionar valores no topo de cada barra
for bar, valor in zip(bars, df["duration_medio"]):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.5, f"{valor:.2f}",
             ha='center', va='bottom', fontsize=10)

# Labels e título
plt.ylabel('Duração Média (s)')
plt.xlabel('Modelo')
plt.title('Duração Média por Modelo')

# Visual limpo
plt.grid(False)
plt.tight_layout()
plt.show()
