# %% [markdown]
# <a href="https://colab.research.google.com/github/Lariiuki/Pos-Deep-Learning/blob/main/Projeto_DeepLearning_Grupo12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto: Análise e Geração de Relatório para Dados Tabulares – Grupo 12
# **Integrantes:** Danilo Falcão,  Getúlio, Larissa Akemi, Ricardo Arruda
#
# **Descrição:**
# Este trabalho utiliza o conjunto de dados "Anime Data Set for ML" disponível no Kaggle. Este dataset compreende informações detalhadas sobre uma vasta coleção de animes, totalizando **29.153 entradas e 19 atributos** por entrada. As informações contidas no dataset são cruciais para análise que visam compreender características e tendências no universo dos animes.
#
# **Relevância:**
# Capacidade de oferecer insights sobre o universo de animes, que é um segmento significativo e em constante crescimento dessa indústria. As análises desses dados podem informar decisões estratégicas para produtores, distribuidores e plataformas de streaming.
#
# **Dataset**: [Anime data set for recommendation system](https://www.kaggle.com/datasets/wiltheman/anime-data-set-for-ml)
#
#
#  Esse conjunto de dados contém informações sobre animes, incluindo
#
# | Nome da Coluna       | Descrição                                                                 |
# |----------------------|---------------------------------------------------------------------------|
# | `title`              | Título principal do anime.                                                |
# | `title_english`      | Título oficial em inglês, se disponível.                                  |
# | `title_japanese`     | Título original em japonês.                                               |
# | `image`              | URL da imagem de capa do anime.                                           |
# | `aired_from`         | Data de início da exibição do anime.                                      |
# | `aired_to`           | Data de término da exibição do anime.                                     |
# | `synopsis`           | Breve descrição ou resumo da história do anime.                           |
# | `status`             | Status de exibição (ex: Finalizado, Em exibição, Não lançado).            |
# | `episodes`           | Número total de episódios.                                                |
# | `rating`             | Faixa etária recomendada (ex: PG-13, R).                                  |
# | `rank`               | Posição do anime no ranking geral com base nas avaliações dos usuários.   |
# | `popularity`         | Posição no ranking de popularidade com base na quantidade de membros.     |
# | `members`            | Número de usuários que adicionaram o anime às suas listas.                |
# | `favorites`          | Número de usuários que marcaram o anime como favorito.                    |
# | `score`              | Pontuação média atribuída pelos usuários.                                 |
# | `scored_by`          | Número de usuários que avaliaram o anime.                                 |
# | `genres`             | Gêneros do anime (ex: Ação, Fantasia).                                    |
# | `themes`             | Temas associados ao anime (ex: Escola, Superpoder).                       |
# | `demographics`       | Público-alvo do anime (ex: Shounen, Seinen).                              |

# %%
import kagglehub

path = kagglehub.dataset_download("wiltheman/anime-data-set-for-ml")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/anime-data-set-for-ml

# %%
import os

print(os.listdir(path))
# Out:
# ['65k_anime_data.csv']

# %%
import pandas as pd
import os

csv_file = os.path.join(path, '65k_anime_data.csv')

df = pd.read_csv(csv_file)

df.head()
# Out:
#                              title            title_english  \
# 0                     Cowboy Bebop             Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2                           Trigun                   Trigun
# 3               Witch Hunter Robin       Witch Hunter Robin
# 4                   Bouken Ou Beet   Beet the Vandel Buster
#
#                      title_japanese  \
# 0                         カウボーイビバップ
# 1                    カウボーイビバップ 天国の扉
# 2                             トライガン
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                            冒険王ビィト
#
#                                                image  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/1130/...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...
#
# ...

# %%
df.shape
# Out:
# (29153, 19)

# %%
df.columns
# Out:
# Index(['title', 'title_english', 'title_japanese', 'image', 'aired_from',
#        'aired_to', 'synopsis', 'status', 'episodes', 'rating', 'rank',
#        'popularity', 'members', 'favorites', 'score', 'scored_by', 'genres',
#        'themes', 'demographics'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29153 entries, 0 to 29152
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           29153 non-null  object
#  1   title_english   12475 non-null  object
#  2   title_japanese  28931 non-null  object
#  3   image           29153 non-null  object
#  4   aired_from      4123 non-null   object
#  5   aired_to        2107 non-null   object
#  6   synopsis        23970 non-null  object
#  7   status          29153 non-null  object
#  8   episodes        29153 non-null  float64
#  9   rating          28467 non-null  object
#  10  rank            22361 non-null  float64
#  11  popularity      29153 non-null  int64
#  12  members         29153 non-null  int64
#  13  favorites       29153 non-null  int64
#  14  score           18681 non-null  float64
#  15  scored_by       18681 non-null  float64
#  16  genres          22979 non-null  object
# ...

# %%
# fazer um novo dataset
df_anime = df.copy()

# %% [markdown]
# # Análise Exploratória de Dados (EDA) - Formatação do dataset

# %% [markdown]
# Vamos verificar o que contém cada coluna que nos interessa

# %%
#df_anime['title'].tolist()

# %%
#df_anime['genres'].tolist()

# %%
#df_anime['aired_to'].tolist()

# %%
#df_anime['aired_from'].tolist()

# %%
#df_anime['favorites'].tolist()

# %% [markdown]
# Rating	Significado
#
# * **G - All Ages:** Livre para todas as idades. Conteúdo seguro para crianças.
# * **PG - Children:**	Conteúdo voltado para crianças, mas os pais devem supervisionar algumas cenas.
# * **PG-13 - Teens 13 or older:**	Recomendado para adolescentes a partir de 13 anos; pode conter violência leve, linguagem moderada ou referências sugestivas.
# * **R+ - Mild Nudity:**	Pode conter nudez leve, conteúdo sexual sugerido ou violência moderada. Geralmente não recomendado para menores de 17.
# * **R - 17+ (violence & profanity):**	Conteúdo adulto, violência explícita, linguagem forte, temas sexuais. Recomendado apenas para maiores de 17 anos

# %%
df_anime['rating'].value_counts()
# Out:
# rating
# PG-13 - Teens 13 or older         10501
# G - All Ages                       9165
# PG - Children                      4421
# R - 17+ (violence & profanity)     1587
# Rx - Hentai                        1577
# R+ - Mild Nudity                   1216
# Name: count, dtype: int64

# %% [markdown]
# **Formatando as datas**
#
# Percebemos que as datas estão no formato data e hora e não utilizaremos a hora para nenhuma análise. Iremos retirar e deixarmos no formato somente de data.

# %%
# Converter 'aired_from' e 'aired_to' para datetime, mantendo apenas a data
df_anime['aired_from'] = pd.to_datetime(df_anime['aired_from'], errors='coerce')
df_anime['aired_to'] = pd.to_datetime(df_anime['aired_to'], errors='coerce')

# %%
# Encontrar a data mínima e máxima nas colunas 'aired_from' e 'aired_to'
min_aired_from = df_anime['aired_from'].min().strftime('%d/%m/%Y')
max_aired_from = df_anime['aired_from'].max().strftime('%d/%m/%Y')
min_aired_to = df_anime['aired_to'].min().strftime('%d/%m/%Y')
max_aired_to = df_anime['aired_to'].max().strftime('%d/%m/%Y')

print(f"Range da data de início de exibição (aired_from): {min_aired_from} a {max_aired_from}")
print(f"Range da data de fim de exibição (aired_to): {min_aired_to} a {max_aired_to}")
# Out:
# Range da data de início de exibição (aired_from): 01/01/1926 a 01/01/2027
# Range da data de fim de exibição (aired_to): 24/11/1965 a 10/04/2026

# %%
df_anime['aired_from'] = df_anime['aired_from'].dt.normalize()
df_anime['aired_to'] = df_anime['aired_to'].dt.normalize()

# %%
# Exibir as primeiras linhas para verificar a transformação
df_anime[['aired_from', 'aired_to']].head()
# Out:
#                  aired_from                  aired_to
# 0 1998-04-03 00:00:00+00:00 1999-04-24 00:00:00+00:00
# 1 2001-09-01 00:00:00+00:00                       NaT
# 2 1998-04-01 00:00:00+00:00 1998-09-30 00:00:00+00:00
# 3 2002-07-03 00:00:00+00:00 2002-12-25 00:00:00+00:00
# 4 2004-09-30 00:00:00+00:00 2005-09-29 00:00:00+00:00

# %% [markdown]
#  **Formatação de gêneros**

# %%
df_anime.head()
# Out:
#                              title            title_english  \
# 0                     Cowboy Bebop             Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2                           Trigun                   Trigun
# 3               Witch Hunter Robin       Witch Hunter Robin
# 4                   Bouken Ou Beet   Beet the Vandel Buster
#
#                      title_japanese  \
# 0                         カウボーイビバップ
# 1                    カウボーイビバップ 天国の扉
# 2                             トライガン
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                            冒険王ビィト
#
#                                                image  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/1130/...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...
#
# ...

# %%
# Verificar os valores únicos na coluna 'genres' e sua contagem
print("Contagem de valores na coluna 'genres':")
display(df_anime['genres'].value_counts())

# Opcional: Ver os valores únicos (sem contagem)
#print("\nValores únicos na coluna 'genres':")
#display(df['genres'].unique())
# Out:
# Contagem de valores na coluna 'genres':
# genres
# Comedy                                                             2701
# Fantasy                                                            1488
# Hentai                                                             1296
# Slice of Life                                                       842
# Avant Garde                                                         808
#                                                                    ...
# Avant Garde, Award Winning, Supernatural                              1
# Action, Fantasy, Suspense                                             1
# Comedy, Romance, Suspense                                             1
# Avant Garde, Comedy, Supernatural                                     1
# Action, Adventure, Comedy, Drama, Mystery, Sci-Fi, Supernatural       1
# Name: count, Length: 936, dtype: int64

# %%
# Lidar com valores ausentes na coluna 'genres' preenchendo com uma string vazia para evitar erros ao splitar
df_anime['genres'] = df_anime['genres'].fillna('')

# Separar os gêneros em listas
df_anime['genres'] = df_anime['genres'].str.split(', ')

# Exibir as primeiras linhas para verificar a nova coluna
print("DataFrame com a coluna 'genres' como lista:")
display(df_anime['genres'].head())
# Out:
# DataFrame com a coluna 'genres' como lista:
# 0           [Action, Award Winning, Sci-Fi]
# 1                          [Action, Sci-Fi]
# 2               [Action, Adventure, Sci-Fi]
# 3    [Action, Drama, Mystery, Supernatural]
# 4              [Action, Adventure, Fantasy]
# Name: genres, dtype: object

# %%
# Se quiser manter a coluna com os gêneros filtrados e sem strings vazias:
df_anime['genres'] = df_anime['genres'].apply(lambda gs: [g for g in gs if g != ''])

# %%
df_anime.head()
# Out:
#                              title            title_english  \
# 0                     Cowboy Bebop             Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2                           Trigun                   Trigun
# 3               Witch Hunter Robin       Witch Hunter Robin
# 4                   Bouken Ou Beet   Beet the Vandel Buster
#
#                      title_japanese  \
# 0                         カウボーイビバップ
# 1                    カウボーイビバップ 天国の扉
# 2                             トライガン
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                            冒険王ビィト
#
#                                                image  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/1130/...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...
#
# ...

# %% [markdown]
# **Formatação dos temas**

# %%
# Lidar com valores ausentes na coluna 'genres' preenchendo com uma string vazia para evitar erros ao splitar
df_anime['themes'] = df_anime['themes'].fillna('')

# Separar os gêneros em listas
df_anime['themes'] = df_anime['themes'].str.split(', ')

# Exibir as primeiras linhas para verificar a nova coluna
print("DataFrame com a coluna 'genres' como lista:")
display(df_anime['themes'].head())
# Out:
# DataFrame com a coluna 'genres' como lista:
# 0    [Adult Cast, Space]
# 1    [Adult Cast, Space]
# 2           [Adult Cast]
# 3            [Detective]
# 4                     []
# Name: themes, dtype: object

# %%
# Se quiser manter a coluna com os gêneros filtrados e sem strings vazias:
df_anime['themes'] = df_anime['themes'].apply(lambda gs: [g for g in gs if g != ''])

# %%
df_anime.head()
# Out:
#                              title            title_english  \
# 0                     Cowboy Bebop             Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2                           Trigun                   Trigun
# 3               Witch Hunter Robin       Witch Hunter Robin
# 4                   Bouken Ou Beet   Beet the Vandel Buster
#
#                      title_japanese  \
# 0                         カウボーイビバップ
# 1                    カウボーイビバップ 天国の扉
# 2                             トライガン
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                            冒険王ビィト
#
#                                                image  \
# 0  https://cdn.myanimelist.net/images/anime/4/196...
# 1  https://cdn.myanimelist.net/images/anime/1439/...
# 2  https://cdn.myanimelist.net/images/anime/1130/...
# 3  https://cdn.myanimelist.net/images/anime/10/19...
# 4  https://cdn.myanimelist.net/images/anime/7/215...
#
# ...

# %% [markdown]
# **Observações sobre a qualidade dos dados**
#
# Durante a análise exploratória, foi identificado que algumas colunas possuem um número substancial de valores ausentes. As colunas 'aired_from', 'aired_to', 'release_year', 'title_english', 'demographics', 'themes', 'genres', 'score', 'scored_by' e 'rank' são as que mais demandam estratefias de tratamento de dados faltantes que vai depender dos objetivos da análise.

# %%
df_anime[['score', 'scored_by', 'rank']].describe()
# Out:
#               score     scored_by          rank
# count  18681.000000  1.868100e+04  22361.000000
# mean       6.397942  2.994750e+04  10671.669916
# std        0.890524  1.215179e+05   6433.922127
# min        1.890000  1.010000e+02      0.000000
# 25%        5.780000  3.400000e+02   5088.000000
# 50%        6.370000  1.549000e+03  10675.000000
# 75%        7.030000  1.013800e+04  16293.000000
# max        9.300000  2.952092e+06  21863.000000

# %% [markdown]
# Olhando para a média (6.39) e a mediana (50% é igual 6.37), elas são bem próximas. Isso sugere que a distribuição da coluna 'score' pode não ter muitos outliers extremos que distorceriam a média significantivamente. No entando, a coluna 'scored_by' (número de usuários que avaliaram), que está relacionada, tem uma grande diferença entre a média e a mediana, indicando outiliers.
#
# Para a coluna **'score'**, a **mediana** pode ser uma escolha ligeiramente mais segura para imputação, caso existam alguns outliers que não sejam imediantamente aparentes apenas pela média e mediana próximas.

# %%
median_score = df_anime['score'].median()
df_anime['score'].fillna(median_score, inplace=True)
# Out:
# /tmp/ipython-input-3514667688.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_anime['score'].fillna(median_score, inplace=True)

# %%
# Verificar se ainda existem valores ausentes na coluna 'score'
print("Número de valores ausentes na coluna 'score' após a imputação:")
df_anime['score'].isnull().sum()
# Out:
# Número de valores ausentes na coluna 'score' após a imputação:
# np.int64(0)

# %%
#fazer mais um dataset com as colunas que iremos utilizar
df_anime_v2 = df_anime[['title', 'aired_from', 'synopsis', 'status', 'episodes', 'rating', 'rank', 'popularity', 'members', 'favorites', 'score', 'scored_by', 'genres', 'themes', 'demographics']]
df_anime_v2.head()
# Out:
#                              title                aired_from  \
# 0                     Cowboy Bebop 1998-04-03 00:00:00+00:00
# 1  Cowboy Bebop: Tengoku no Tobira 2001-09-01 00:00:00+00:00
# 2                           Trigun 1998-04-01 00:00:00+00:00
# 3               Witch Hunter Robin 2002-07-03 00:00:00+00:00
# 4                   Bouken Ou Beet 2004-09-30 00:00:00+00:00
#
#                                             synopsis           status  \
# 0  Crime is timeless. By the year 2071, humanity ...  Finished Airing
# 1  Another day, another bounty—such is the life o...  Finished Airing
# 2  Vash the Stampede is the man with a $$60,000,0...  Finished Airing
# 3  Though hidden away from the general public, Wi...  Finished Airing
# 4  It is the dark century and the people are suff...  Finished Airing
#
#    episodes                          rating    rank  popularity  members  \
# 0      26.0  R - 17+ (violence & profanity)    47.0          42  1981397
# ...

# %%
df_anime_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29153 entries, 0 to 29152
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         29153 non-null  object
#  1   aired_from    4123 non-null   datetime64[ns, UTC]
#  2   synopsis      23970 non-null  object
#  3   status        29153 non-null  object
#  4   episodes      29153 non-null  float64
#  5   rating        28467 non-null  object
#  6   rank          22361 non-null  float64
#  7   popularity    29153 non-null  int64
#  8   members       29153 non-null  int64
#  9   favorites     29153 non-null  int64
#  10  score         29153 non-null  float64
#  11  scored_by     18681 non-null  float64
#  12  genres        29153 non-null  object
#  13  themes        29153 non-null  object
#  14  demographics  10788 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(4), int64(3), object(7)
# memory usage: 3.3+ MB

# %% [markdown]
# **Removendo valores do dataset**
#
# Durante a fase de limpeza e pré-processamento do dataset de animes, identificamos que a coluna 'demographics' apresentava uma quantidade significativa de valores ausentes, correspondendo a aproximadamente 63% do total de entradas. Considerando os objetivos deste projeto, que incluem a análise de características e tendências dos animes, a informação demográfica é um atributo potencialmente relevante para segmentar e compreender o público-alvo de diferentes títulos.
#
# Diante da alta taxa de dados faltantes e da natureza categórica da coluna 'demographics', optamos pela estratégia de remover as linhas que possuíam valores nulos especificamente nesta coluna.
#
# Portanto, a remoção das linhas com valores ausentes na coluna 'demographics' foi uma escolha deliberada para garantir a qualidade e a validade das análises que envolvem este atributo crucial, priorizando a integridade da informação demográfica para os animes onde ela está disponível, sem comprometer a viabilidade do projeto em termos de volume de dados

# %%
# Remover linhas com valores ausentes na coluna 'demographics'
df_anime_filtered_demographics = df_anime_v2.dropna(subset=['demographics']).copy()

# Verificar o número de linhas restantes
print(f"Número de linhas após remover NaNs em 'demographics': {len(df_anime_filtered_demographics)}")

# Verificar se ainda existem valores ausentes na coluna 'demographics'
print("\nNúmero de valores ausentes na coluna 'demographics' no novo DataFrame:")
display(df_anime_filtered_demographics['demographics'].isnull().sum())

# Exibir as primeiras linhas do novo DataFrame
display(df_anime_filtered_demographics.head())
# Out:
# Número de linhas após remover NaNs em 'demographics': 10788
#
# Número de valores ausentes na coluna 'demographics' no novo DataFrame:
# np.int64(0)
#                         title                aired_from  \
# 2                      Trigun 1998-04-01 00:00:00+00:00
# 4              Bouken Ou Beet 2004-09-30 00:00:00+00:00
# 5                Eyeshield 21 2005-04-06 00:00:00+00:00
# 6        Hachimitsu to Clover 2005-04-15 00:00:00+00:00
# 7  Hungry Heart: Wild Striker 2002-09-11 00:00:00+00:00
#
#                                             synopsis           status  \
# 2  Vash the Stampede is the man with a $$60,000,0...  Finished Airing
# 4  It is the dark century and the people are suff...  Finished Airing
# 5  Shy, reserved, and small-statured, Deimon High...  Finished Airing
# 6  Yuuta Takemoto, a sophomore at an arts college...  Finished Airing
# 7  As the younger brother of Japanese soccer star...  Finished Airing
#
# ...

# %%
df_anime_filtered_demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10788 entries, 2 to 29149
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         10788 non-null  object
#  1   aired_from    1360 non-null   datetime64[ns, UTC]
#  2   synopsis      7354 non-null   object
#  3   status        10788 non-null  object
#  4   episodes      10788 non-null  float64
#  5   rating        10663 non-null  object
#  6   rank          9421 non-null   float64
#  7   popularity    10788 non-null  int64
#  8   members       10788 non-null  int64
#  9   favorites     10788 non-null  int64
#  10  score         10788 non-null  float64
#  11  scored_by     5171 non-null   float64
#  12  genres        10788 non-null  object
#  13  themes        10788 non-null  object
#  14  demographics  10788 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(4), int64(3), object(7)
# memory usage: 1.3+ MB

# %% [markdown]
#  **Buscando missing values**

# %%
original_missing_values = df.isnull().sum()
original_missing_percentage = (original_missing_values / len(df)) * 100

missing_values = df_anime_filtered_demographics.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100

print("Número de valores faltantes por coluna, base original")
display(original_missing_values)

print("\n\nNúmero de valores faltantes por coluna, base modificada")
display(missing_values)
# Out:
# Número de valores faltantes por coluna, base original
# title                 0
# title_english     16678
# title_japanese      222
# image                 0
# aired_from        25030
# aired_to          27046
# synopsis           5183
# status                0
# episodes              0
# rating              686
# rank               6792
# popularity            0
# members               0
# favorites             0
# score             10472
# scored_by         10472
# genres             6174
# themes            11918
# demographics      18365
# dtype: int64
# Número de valores faltantes por coluna, base modificada
# title              0
# aired_from      9428
# synopsis        3434
# status             0
# episodes           0
# rating           125
# rank            1367
# popularity         0
# members            0
# favorites          0
# score              0
# scored_by       5617
# genres             0
# themes             0
# demographics       0
# dtype: int64

# %%
print("Porcentagem de valores faltantes por coluna, base original")
display(original_missing_percentage)

print("\n\nPorcentagem de valores faltantes por coluna, base modificada")
display(missing_percentage)
# Out:
# Porcentagem de valores faltantes por coluna, base original
# title              0.000000
# title_english     57.208521
# title_japanese     0.761500
# image              0.000000
# aired_from        85.857373
# aired_to          92.772613
# synopsis          17.778616
# status             0.000000
# episodes           0.000000
# rating             2.353103
# rank              23.297774
# popularity         0.000000
# members            0.000000
# favorites          0.000000
# score             35.920831
# scored_by         35.920831
# genres            21.177923
# themes            40.880870
# demographics      62.995232
# dtype: float64
# Porcentagem de valores faltantes por coluna, base modificada
# title            0.000000
# aired_from      32.339725
# synopsis        11.779234
# status           0.000000
# episodes         0.000000
# rating           0.428772
# rank             4.689054
# popularity       0.000000
# members          0.000000
# favorites        0.000000
# ...

# %%
num_linhas_zero = (df_anime_filtered_demographics['episodes'] == 0).sum()

print(f"Número de linhas com episodes = 0: {num_linhas_zero}")
# Out:
# Número de linhas com episodes = 0: 208

# %%
animes_zero_episodios = df_anime_filtered_demographics[df_anime_filtered_demographics['episodes'] == 0]

print(animes_zero_episodios[['title', 'episodes']].head(10))
# Out:
#                          title  episodes
# 11                   One Piece       0.0
# 211            Meitantei Conan       0.0
# 871           Crayon Shin-chan       0.0
# 1093          Nintama Rantarou       0.0
# 1787        Sore Ike! Anpanman       0.0
# 3639                 Ojarumaru       0.0
# 4465  Chibi Maruko-chan (1995)       0.0
# 5316                 Hanakappa       0.0
# 5465           Doraemon (2005)       0.0
# 7957        Shimajirou no Wow!       0.0

# %% [markdown]
# **Aprimoramento da coluna 'episodes'**
#
# Observamos que a coluna 'episodes' contém valores inconsistentes, especialmente para animes de longa duração, que possuem número de episódios muito maior do que o registrado ou até mesmo valores zerados. Para lidar com essas inconsistências, faremos um tratamento dos dados convertendo a coluna em uma variável categórica, facilitando a análise e a interpretação dos diferentes perfis de duração dos animes.

# %%
import numpy as np
df_anime_filtered_demographics['episodes'] = df_anime_filtered_demographics['episodes'].replace(0, np.nan)

# %%
df_known_episodes = df_anime_filtered_demographics[df_anime_filtered_demographics['episodes'] > 0]

# %%
def categorize_episodes(x):
    if pd.isna(x):
        return "Desconhecido"
    elif x == 0:
        return "Iniciando (>5)"
    elif x < 12:
        return "Curto (<12)"
    elif x < 50:
        return "Médio (12-49)"
    else:
        return "Longo (50+)"

df_anime_filtered_demographics['episodes_category'] = df_anime_filtered_demographics['episodes'].apply(categorize_episodes)

# %% [markdown]
# **Aprimoramento da coluna 'rank'**

# %%
valores_rank = pd.to_numeric(df_anime_filtered_demographics['rank'], errors='coerce').dropna().unique()

# Ordena e imprime valores como float simples (sem np.float64)
valores_rank_ordenados = sorted([float(v) for v in valores_rank])
# print(valores_rank_ordenados)

contagem_rank = df_anime_filtered_demographics['rank'].value_counts()

# Filtra apenas os que se repetem
rank_repetidos = contagem_rank[contagem_rank > 1]

# Exibe os ranks duplicados e quantas vezes cada um aparece
print(rank_repetidos)
# Out:
# rank
# 0.0        76
# 16791.0     5
# 16789.0     4
# 18976.0     4
# 14250.0     4
#            ..
# 17186.0     2
# 7986.0      2
# 17899.0     2
# 6104.0      2
# 14650.0     2
# Name: count, Length: 1294, dtype: int64

# %%
# deletar todas as linhas que contém o valor 0 na coluna rank
df_anime_filtered_demographics = df_anime_filtered_demographics[
    (df_anime_filtered_demographics['rank'] != 0) &
    (df_anime_filtered_demographics['rank'].notna())
]

# %%
(df_anime_filtered_demographics['rank'] == 0).sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Aprimoramento da coluna 'popularity'**

# %%
(df_anime_filtered_demographics['popularity'] == 0).sum()
# Out:
# np.int64(0)

# %%
df_anime_filtered_demographics['popularity'].describe()
# Out:
# count     9345.000000
# mean     15911.672980
# std       9509.049199
# min          1.000000
# 25%       6242.000000
# 50%      17863.000000
# 75%      25024.000000
# max      28653.000000
# Name: popularity, dtype: float64

# %%
bins = [df_anime_filtered_demographics['popularity'].min()-1, df_anime_filtered_demographics['popularity'].quantile(0.25), df_anime_filtered_demographics['popularity'].quantile(0.5), df_anime_filtered_demographics['popularity'].quantile(0.75), df_anime_filtered_demographics['popularity'].max()]
labels = ['Alta', 'Média-alta', 'Média-baixa', 'Baixa']

df_anime_filtered_demographics['popularity_category'] = pd.cut(df_anime_filtered_demographics['popularity'], bins=bins, labels=labels)

# %%
bins = [0, 3000, 7000, 12000, df['popularity'].max()]
labels = ['Alta', 'Média', 'Baixa Média', 'Baixa']

df['popularity_category'] = pd.cut(df['popularity'], bins=bins, labels=labels)

# %%
df_anime_filtered_demographics.head()
# Out:
#                         title                aired_from  \
# 2                      Trigun 1998-04-01 00:00:00+00:00
# 4              Bouken Ou Beet 2004-09-30 00:00:00+00:00
# 5                Eyeshield 21 2005-04-06 00:00:00+00:00
# 6        Hachimitsu to Clover 2005-04-15 00:00:00+00:00
# 7  Hungry Heart: Wild Striker 2002-09-11 00:00:00+00:00
#
#                                             synopsis           status  \
# 2  Vash the Stampede is the man with a $$60,000,0...  Finished Airing
# 4  It is the dark century and the people are suff...  Finished Airing
# 5  Shy, reserved, and small-statured, Deimon High...  Finished Airing
# 6  Yuuta Takemoto, a sophomore at an arts college...  Finished Airing
# 7  As the younger brother of Japanese soccer star...  Finished Airing
#
#    episodes                     rating    rank  popularity  members  \
# 2      26.0  PG-13 - Teens 13 or older   385.0         261   805264
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
numerical_cols = ['episodes', 'rank', 'popularity','score', 'members', 'favorites', 'scored_by']

num_plots = len(numerical_cols)

cols = 2
rows = (num_plots + 1) // cols

plt.figure(figsize=(12, rows * 2))

for i, col in enumerate(numerical_cols, 1):
    plt.subplot(rows, cols, i)
    sns.boxplot(x=df_anime_filtered_demographics[col].dropna())
    plt.title(f'Distribuição de {col}')
    plt.xlabel(col)

plt.tight_layout()
plt.show()

# %%
df_anime_filtered_demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9345 entries, 2 to 29133
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   title                9345 non-null   object
#  1   aired_from           1228 non-null   datetime64[ns, UTC]
#  2   synopsis             5955 non-null   object
#  3   status               9345 non-null   object
#  4   episodes             9265 non-null   float64
#  5   rating               9296 non-null   object
#  6   rank                 9345 non-null   float64
#  7   popularity           9345 non-null   int64
#  8   members              9345 non-null   int64
#  9   favorites            9345 non-null   int64
#  10  score                9345 non-null   float64
#  11  scored_by            4619 non-null   float64
#  12  genres               9345 non-null   object
#  13  themes               9345 non-null   object
#  14  demographics         9345 non-null   object
# ...

# %% [markdown]
# # **Análises**

# %% [markdown]
# ## **Correlação**
#
# **Associação entre variáveis:** Quais pares numéricos têm maior correlação?

# %%
num_cols = df_anime_filtered_demographics.select_dtypes(include='number').columns.tolist()
corr = df_anime_filtered_demographics[num_cols].corr()

plt.figure(figsize=(6,5))
plt.imshow(corr, interpolation='nearest')
plt.title("Matriz de Correlação")
plt.colorbar()
plt.xticks(ticks=range(len(num_cols)), labels=num_cols, rotation=90)
plt.yticks(ticks=range(len(num_cols)), labels=num_cols)
plt.tight_layout()
plt.show()

pairs = []
for i in range(len(num_cols)):
    for j in range(i+1, len(num_cols)):
        pairs.append((num_cols[i], num_cols[j], corr.iloc[i, j]))
pairs_sorted = sorted(pairs, key=lambda x: abs(x[2]), reverse=True)[:3]
print("Resposta P3: Maiores correlações (valor absoluto):")
for a,b,v in pairs_sorted:
    print(f" - {a} x {b}: {v:.2f}")
# Out:
# Resposta P3: Maiores correlações (valor absoluto):
#  - members x scored_by: 0.99
#  - rank x popularity: 0.90
#  - favorites x scored_by: 0.78

# %%
numeric_cols = df_anime_filtered_demographics.select_dtypes(include='number')

plt.figure(figsize=(10, 8))
sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlação')
plt.show()

# %% [markdown]
# Com base na análise de correlação:
#
#
# *   **members x scored_by (0.99):** Essa correlação é esperada, pois animes com mais membros tendem a ter mais avaliações.
# *   **rank x popularity (0.90):** Isso sugere que animes com um bom ranking geral (menor valor de rank) também são populares (menor valor de popularity).
# *   **favorites x scored_by (0.78):** Isso indica que animes com muitos favoritos também tendem a ter mais avaliações.

# %% [markdown]
# **members x scored_by (0.99)**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_anime_filtered_demographics, x='members', y='scored_by')
plt.grid(False)
plt.title('Correlação entre Members e Scored_by')
plt.xlabel('Members')
plt.ylabel('Scored_by')
plt.show()

# %%
top_score_animes = df_anime_filtered_demographics.sort_values(by='scored_by', ascending=False)

print("Top 10 animes maior número de avaliações (scored_by):")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites', 'scored_by']].head(10))

top_score_animes = df_anime_filtered_demographics.sort_values(by='members', ascending=False)

print("\n\nTop 10 animes maior número de membros:")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites', 'scored_by']].head(10))
# Out:
# Top 10 animes maior número de avaliações (scored_by):
#                                   title  score    rank  members  popularity  \
# 7424                 Shingeki no Kyojin   8.56   117.0  4188784           1
# 1393                         Death Note   8.62    92.0  4128800           2
# 10400                     One Punch Man   8.48   155.0  3404988           4
# 14519                  Kimetsu no Yaiba   8.43   187.0  3281711           5
# 3960   Fullmetal Alchemist: Brotherhood   9.10     2.0  3541474           3
# 11126             Boku no Hero Academia   7.84   986.0  3189172           7
# 10                               Naruto   8.01   674.0  3006981           9
# 9345        Shingeki no Kyojin Season 2   8.53   133.0  2899674          12
# 8612                        Tokyo Ghoul   7.79  1109.0  2962695          10
# 6452             Hunter x Hunter (2011)   9.03     8.0  3044411           8
#
#        favorites  scored_by
# 7424      181378  2952092.0
# ...

# %% [markdown]
# **rank x popularity (0.87)**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_anime_filtered_demographics, x='rank', y='popularity')
plt.grid(False)
plt.title('Correlação entre Rank e Popularity')
plt.xlabel('Rank (quanto menor, melhor)')
plt.ylabel('Popularity (quanto menor, melhor)')
plt.show()

# %%
top_score_animes = df_anime_filtered_demographics.sort_values(by='rank', ascending=True)

print("Top 10 animes menor rank:")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites']].head(10))

top_score_animes = df_anime_filtered_demographics.sort_values(by='popularity', ascending=True)

print("\n\nTop 10 animes por popularidade:")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites']].head(10))
# Out:
# Top 10 animes menor rank:
#                                     title  score  rank  members  popularity  \
# 23055                   Sousou no Frieren   9.30   1.0  1173458         137
# 3960     Fullmetal Alchemist: Brotherhood   9.10   2.0  3541474           3
# 14841  Shingeki no Kyojin Season 3 Part 2   9.05   4.0  2468872          21
# 9872                             Gintama°   9.05   5.0   671470         343
# 15497                  Gintama: The Final   9.04   6.0   171799        1522
# 27683                One Piece Fan Letter   9.04   7.0   119516        2028
# 6452               Hunter x Hunter (2011)   9.03   8.0  3044411           8
# 5985                             Gintama'   9.02   9.0   592834         404
# 7236                  Gintama': Enchousen   9.02  10.0   347211         752
# 16579           Bleach: Sennen Kessen-hen   8.99  12.0   647815         361
#
#        favorites
# 23055      72720
# 3960      234763
# 14841      61363
# 9872       17233
# ...

# %% [markdown]
# **favorites x scored_by (0.78)**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_anime_filtered_demographics, x='scored_by', y='favorites')
plt.grid(False)
plt.title('Correlação entre Favorites e Scored_by')
plt.xlabel('Favorites')
plt.ylabel('Número de avaliações')
plt.show()

# %%
top_score_animes = df_anime_filtered_demographics.sort_values(by='scored_by', ascending=False)

print("Top 10 animes maior número de avaliações (scored_by):")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites', 'scored_by']].head(10))

top_score_animes = df_anime_filtered_demographics.sort_values(by='favorites', ascending=False)

print("\n\nTop 10 animes entre os favoritos:")
display(top_score_animes[['title', 'score', 'rank', 'members', 'popularity', 'favorites', 'scored_by']].head(10))
# Out:
# Top 10 animes maior número de avaliações (scored_by):
#                                   title  score    rank  members  popularity  \
# 7424                 Shingeki no Kyojin   8.56   117.0  4188784           1
# 1393                         Death Note   8.62    92.0  4128800           2
# 10400                     One Punch Man   8.48   155.0  3404988           4
# 14519                  Kimetsu no Yaiba   8.43   187.0  3281711           5
# 3960   Fullmetal Alchemist: Brotherhood   9.10     2.0  3541474           3
# 11126             Boku no Hero Academia   7.84   986.0  3189172           7
# 10                               Naruto   8.01   674.0  3006981           9
# 9345        Shingeki no Kyojin Season 2   8.53   133.0  2899674          12
# 8612                        Tokyo Ghoul   7.79  1109.0  2962695          10
# 6452             Hunter x Hunter (2011)   9.03     8.0  3044411           8
#
#        favorites  scored_by
# 7424      181378  2952092.0
# ...

# %% [markdown]
# **Existe correlação entre popularidade (popularity) e nota (score)?**

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='popularity', y='score', alpha=0.5)
plt.title('Correlação entre Popularidade e Score')
plt.xlabel('Popularidade')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# ****

# %% [markdown]
# **A duração do anime está interligada com o popularidade?**
#
# Limites das categorias:
# * Alta: de 1 até 3234
# * Média-alta: de 3234 até 6194
# * Média-baixa: de 6194 até 10172
# * Baixa: de 10172 até 28653
#
# **Conclusão**
#
# * Animes de média duração são os mais numeros e diversos em popularidade.
# * Animes curtos têm uma concentração maior nas categorias de popularidade mais baixas. Isso indica que animes com poucos episódios tendem a ter um público menor ou menos engajamento.

# %%
plt.figure(figsize=(14, 7))
df_filtered = df_anime_filtered_demographics[
    (df_anime_filtered_demographics['episodes_category'] != "Desconhecido")
]

ax = sns.countplot(data=df_filtered, x='episodes_category', hue='popularity_category')
ax.grid(False)

plt.title('Contagem de Animes por Categoria de Episódios e Popularidade')
plt.xlabel('Categoria de Episódios')
plt.ylabel('Número de Animes')
plt.legend(title='Popularidade')
plt.xticks(rotation=0)

for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(
            x=p.get_x() + p.get_width() / 2,
            y=height + 1,
            s=int(height),
            ha='center',
            va='bottom',
            fontsize=10
        )

plt.tight_layout()
plt.show()

# %% [markdown]
# **Top 10 Animes com Maior Número de Membros**

# %%
# Filtrar os 10 maiores por número de membros
top_members = df_anime_filtered_demographics.sort_values(by='members', ascending=False).head(10)

plt.figure(figsize=(18, 10))
sns.barplot(
    data=top_members,
    x='members',
    y='title',
    palette='viridis'
)
plt.grid(False)

plt.title('Top 10 Animes com Maior Número de Membros', fontsize=16)
plt.xlabel('Número de Membros', fontsize=10)
plt.ylabel('Título', fontsize=10)

for index, value in enumerate(top_members['members']):
    plt.text(value + 10000, index, f'{value:,}', va='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2556084122.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
#  **Quais são os tipos de generos mais populares dos animes?**

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# Obter os dados de contagem usando a Series 'all_genres' criada na célula anterior
all_genres = df_anime_filtered_demographics['genres'].explode()
genre_counts = all_genres.value_counts()

plt.figure(figsize=(14, 7))
ax = sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='viridis')
ax.grid(False)

plt.xticks(rotation=90)

plt.title('Contagem de Animes por Gênero', fontsize=16)
plt.xlabel('Gênero', fontsize=12)
plt.ylabel('Número de Animes', fontsize=12)

for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge', padding=3)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-665324893.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='viridis')

# %% [markdown]
# **Quais são os temas mais frequentes entre os animes com score acima de 8?**
#
# Este gráfico mostra os 10 temas que aparecem com mais frequência em animes que possuem uma pontuação de 8 ou mais. Podemos observar que "Adult Cast" é o tema mais comum entre esses animes com alta pontuação, seguido por "Detective" e "Military" e "School". Isso sugere que animes com esses temas tendem a ser bem avaliados pelos usuários.

# %%
df_high_score = df_anime_filtered_demographics[df_anime_filtered_demographics['score'] >= 8].copy()

all_themes_high_score = df_high_score['themes'].explode()

temas_populares = all_themes_high_score.value_counts().head(10)

#print("Top 10 temas mais frequentes em animes com score >= 8:")
#display(temas_populares)

# %%
plt.figure(figsize=(14, 7))
ax = sns.barplot(x=temas_populares.index, y=temas_populares.values, palette='viridis')
ax.grid(False)

plt.xticks(rotation=90)
plt.title('Top 10 Temas Mais Frequentes em Animes com Score ≥ 8', fontsize=16)
plt.xlabel('Tema', fontsize=12)
plt.ylabel('Número de Animes', fontsize=12)

for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge', padding=3)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4050476807.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=temas_populares.index, y=temas_populares.values, palette='viridis')

# %% [markdown]
# **Qual é a distribuição de ratings (G, PG, PG-13, R+, R)?**

# %%
rating_counts = df_anime_filtered_demographics['rating'].dropna().value_counts()

plt.figure(figsize=(10, 7))
ax = sns.barplot(
    x=rating_counts.values,
    y=rating_counts.index,
    palette='viridis',
    orient='h'
)
ax.grid(False)

plt.title('Distribuição de Animes por Rating', fontsize=16)
plt.xlabel('Número de Animes', fontsize=12)
plt.ylabel('Rating', fontsize=12)

for bar in ax.patches:
    width = bar.get_width()
    ax.text(width + 3, bar.get_y() + bar.get_height()/2, f'{int(width)}', va='center')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-693667668.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %% [markdown]
# **Qual é a distribuição do público alvo?**

# %%
df_demo_exploded = df_anime_filtered_demographics['demographics'].dropna().explode()

# %%
df_demo_exploded = df_anime_filtered_demographics['demographics'].dropna().str.split(',').explode()

# %%
demographics_counts = df_demo_exploded.value_counts()

plt.figure(figsize=(10, 7))
ax = sns.barplot(
    x=demographics_counts.values,
    y=demographics_counts.index,
    palette='viridis'
)
ax.grid(False)

plt.title('Contagem de Animes por Público-alvo', fontsize=16)
plt.xlabel('Número de Animes', fontsize=12)
plt.ylabel('Público-alvo', fontsize=12)

for bar in ax.patches:
    width = bar.get_width()
    ax.text(width + 1, bar.get_y() + bar.get_height()/2, f'{int(width)}', va='center')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3615797247.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %% [markdown]
# **Que gêneros têm mais animes para Kids?**
#
# Crianças tendem a focar em temas leves, divertidos e imaginativos, como Comedy, Fantasy e Adventure sendo os gêneros dominantes.
#
# Comedy é o gênero mais popular entre animes Kids, indicando que o humor é um elemento muito presente e apreciado em animes voltados para o público infantil.

# %%
df_filtered = df_anime_filtered_demographics[
    df_anime_filtered_demographics['rating'].isin(['PG - Children'])
]

all_genres = df_filtered['genres'].explode()

genre_counts = all_genres.value_counts()

plt.figure(figsize=(10, 8))
ax = sns.barplot(x=genre_counts.values, y=genre_counts.index, palette='viridis', orient='h')
ax.grid(False)

plt.title('Gêneros mais comuns em animes Kids', fontsize=16)
plt.xlabel('Número de Animes', fontsize=12)
plt.ylabel('Gênero', fontsize=12)

for bar in ax.patches:
    width = bar.get_width()
    ax.text(width + 1, bar.get_y() + bar.get_height()/2, f'{int(width)}', va='center')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2627846069.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=genre_counts.values, y=genre_counts.index, palette='viridis', orient='h')

# %% [markdown]
# **Quais gêneros de anime mais populares são mais comuns entre adolescentes e adultos?**
#
# **Tradução:**
# * **Shounen:**	Adolescentes do sexo masculino (aprox. 12–18 anos). Geralmente foca em ação, aventura, amizade e superação, com protagonistas jovens que evoluem durante a história. Ex.: Naruto, One Piece.
# * **Shoujo:**	Adolescentes do sexo feminino (aprox. 12–18 anos). Costuma explorar romance, drama, relacionamentos e emoções, com protagonistas femininas ou histórias sentimentais. Ex.: Sailor Moon, Fruits Basket.
# * **Seinen:**	Jovens adultos do sexo masculino (aprox. 18–40 anos). Tramas mais complexas, maduras ou violentas, às vezes com temas psicológicos ou políticos. Ex.: Berserk, Tokyo Ghoul.
# * **Josei:**	Jovens adultas do sexo feminino (aprox. 18–40 anos). Foca em relacionamentos e vida adulta, com dramas mais realistas do que em shoujo. Ex.: Nana, Paradise Kiss.
# * **Kids:**	Crianças pequenas. Conteúdo é leve, educativo e seguro, com histórias simples e divertidas. Ex.: Doraemon, Pokemon.
#
# **Conclusão**
#
# * Seinen domina a maioria dos Top 10 gêneros.
# * Comedy e Drama são os gêneros com maior número de animes para ambos os públicos.
# * Alguns gêneros nos Top 10 não possuem representação Josei

# %%
# Explodir os gêneros
df_exploded = df_filtered.explode('genres')

# Calcular popularidade média por gênero
popularity_by_genre = df_exploded.groupby('genres')['popularity'].mean().reset_index()

# Top 10 gêneros
top_genres = popularity_by_genre.sort_values('popularity', ascending=False).head(10)
df_top = df_exploded[df_exploded['genres'].isin(top_genres['genres'])]

# Explodir a coluna demographics (string separada por vírgula)
df_top = df_top.copy()  # evita SettingWithCopyWarning
df_top['demographics'] = df_top['demographics'].dropna().apply(lambda x: x.split(',') if isinstance(x, str) else [x])
df_top = df_top.explode('demographics')
df_top['demographics'] = df_top['demographics'].str.strip()  # remove espaços

# Filtrar para remover Kids, Shounen e Shoujo
df_top = df_top[~df_top['demographics'].isin(['Kids', 'Shounen', 'Shoujo'])]

# Agrupar por gênero e demographics
genre_by_demo = df_top.groupby(['genres', 'demographics']).size().reset_index(name='count')

plt.figure(figsize=(14, 7))
ax = sns.barplot(
    data=genre_by_demo,
    x='genres',
    y='count',
    hue='demographics',
    palette='viridis'
)
ax.grid(False)
plt.xticks(rotation=0, ha='center')

for bar in ax.patches:
    height = bar.get_height()
    ax.text(
        bar.get_x() + bar.get_width()/2,
        height + 1,
        f'{int(height)}',
        ha='center', va='bottom', fontsize=10
    )

plt.xlabel('Gênero', fontsize=12)
plt.ylabel('Número de Animes', fontsize=12)
plt.title('Distribuição de Público-alvo nos Top 10 Gêneros', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **O número de animes produzidos por ano cresceu ou diminuiu ao longo do tempo?**
#
# Houve algum relato histórico talvez na economia inteligada a baixa produção de anime nos periodos entre 2008 atê 2022. Em 2008 houve a crise financeira global que teve impacto direto na indústria de animes.
#
# Antes de 2008, muitos estúdios despendiam fortemente de **vendas de DVDs/Blu-rays** e de merchandising no Japão.
#
# A crise global afetou tanto o **poder de compra** do público japonês quando o **fluxo de investimentos** dos comitês de produção.

# %%
# O número de animes produzidos por ano cresceu ou diminuiu ao longo do tempo?
# Extrair o ano da coluna 'aired_from'
df_anime_filtered_demographics = df_anime_filtered_demographics.dropna(subset=['aired_from'])
df_anime_filtered_demographics['year'] = df_anime_filtered_demographics['aired_from'].dt.year.astype(int)

# Contar o número de animes por ano e ordenar cronologicamente
anime_por_ano = df_anime_filtered_demographics['year'].value_counts().sort_index()

plt.figure(figsize=(15, 8))
ax = anime_por_ano.plot(kind='bar')
ax.grid(False)

for i, valor in enumerate(anime_por_ano):
    ax.text(i, valor + 1, str(valor), ha='center', va='bottom', fontsize=10)

plt.title('Número de Animes Produzidos por Ano', fontsize=16)
plt.xlabel('Ano', fontsize=12)
plt.ylabel('Número de Animes', fontsize=12)

plt.tight_layout()
plt.show()
